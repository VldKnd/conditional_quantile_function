# %%
import numpy as np
import matplotlib.pyplot as plt
import torch

from datasets.synthetic.tictac import TicTacDataset

# %%
# %matplotlib inline

# %%
tt = TicTacDataset(in_dim=5, out_dim=2)
X, Y = tt.sample_joint(1000)

# %%
fig, ax = plt.subplots(1, 1, subplot_kw={'projection': '3d'})
ax.set_xlabel("Y_0")
ax.set_ylabel("Y_1")
ax.set_zlabel("X_0")
ax.scatter(
        Y[:, 0], Y[:, 1], X[:, 0], color="blue", marker="o", s=30, alpha=0.2
    )
fig.show()
# Out:
# /tmp/ipykernel_937003/3294015617.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
